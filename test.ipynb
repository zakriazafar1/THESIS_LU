# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\zafar\OneDrive - Netherlands Institute for Neuroscience\Documents\THESIS_OUTPUTS\PROJECT 2\2. preprocessing\transformed\arousal_feature_matrix_transformed.csv",
                 sep = ";", index_col = 4)
df.head(10)
# Out:
#                subject_id group night_id  stage_rk  start_sec   end_sec  \
# event_idx
# 0          bnbd_nsr_01272   NSR    T0_N2         1   2642.910  2649.883
# 1          bnbd_nsr_01272   NSR    T0_N2         0   2684.570  2721.375
# 2          bnbd_nsr_01272   NSR    T0_N2         2   2832.398  2838.094
# 3          bnbd_nsr_01272   NSR    T0_N2         2   2965.195  2968.605
# 4          bnbd_nsr_01272   NSR    T0_N2         5   5791.691  5800.074
# 5          bnbd_nsr_01272   NSR    T0_N2         5   5993.422  5997.691
# 6          bnbd_nsr_01272   NSR    T0_N2         5   6173.395  6177.980
# 7          bnbd_nsr_01272   NSR    T0_N2         0   6455.402  6472.719
# 8          bnbd_nsr_01272   NSR    T0_N2         1   6585.141  6588.535
# 9          bnbd_nsr_01272   NSR    T0_N2         0   6608.395  6623.344
#
#            duration_sec  sec_prev_event  L_delta_ratio  L_delta_peak_ratio  \
# event_idx
# 0              2.076061             NaN       0.522359            1.003202
# ...

# %%
import statistics

statistics.median(df['ridge_peak_hz'])
# Out:
# 0.405465108

# %%
import numpy as np
from scipy.stats import iqr

iqr(df['ridge_peak_hz'], rng=(25, 75), interpolation='midpoint')
# Out:
# np.float64(0.408128226)
